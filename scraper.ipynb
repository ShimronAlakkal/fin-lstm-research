# %%
from bs4 import BeautifulSoup as bs
import requests as req
import os

# %% [markdown]
# ## The global market indices

# %%
americas_index_url = 'https://www.google.com/finance/markets/indexes/americas'
me_index_url = 'https://www.google.com/finance/markets/indexes/europe-middle-east-africa'
ap_index_url = 'https://www.google.com/finance/markets/indexes/asia-pacific'

# %%
res_americas = req.get(americas_index_url)
res_me = req.get(me_index_url)
res_ap = req.get(ap_index_url)

html_americas = bs(res_americas.text, 'html.parser')
html_me = bs(res_me.text, 'html.parser')
html_ap = bs(res_ap.text, 'html.parser')

# %%
index_names_class = 'ZvmM7'
index_price_class = 'YMlKec'
index_change_class = 'P2Luy Ebnabc'
index_cperc_class = 'JwB6zf'

# %%
americas_index_names = html_americas.find_all("div",class_ = index_names_class)
americas_index_price = html_americas.find_all("div",class_ = index_price_class)
americas_index_change = html_americas.find_all("span",class_ = index_change_class)
americas_index_cperc = html_americas.find_all("div",class_ = index_cperc_class)

me_index_names = html_me.find_all("div",class_ = index_names_class)
me_index_price = html_me.find_all("div",class_ = index_price_class)
me_index_change = html_me.find_all("span",class_ = index_change_class)
me_index_cperc = html_me.find_all("div",class_ = index_cperc_class)

ap_index_names = html_ap.find_all("div",class_ = index_names_class)
ap_index_price = html_ap.find_all("div",class_ = index_price_class)
ap_index_change = html_ap.find_all("span",class_ = index_change_class)
ap_index_cperc = html_ap.find_all("div",class_ = index_cperc_class)

# %%
index_data_map = {}
temp_americas, temp_me, temp_ap = {}, {}, {}

for i in range(len(americas_index_change)):
    temp_americas[americas_index_names[i].get_text()] = {'ltp': americas_index_price[i].get_text(), 'change' : americas_index_change[i].get_text(), 'perc change' : americas_index_cperc[i].get_text()}
index_data_map['americas'] = temp_americas

for i in range(len(me_index_change)):
    temp_me[me_index_names[i].get_text()] = { 'ltp': me_index_price[i].get_text(), 'change': me_index_change[i].get_text(), 'perc change' : me_index_cperc[i].get_text()}
index_data_map['me'] = temp_me

for i in range(len(ap_index_change)):
    temp_ap[ap_index_names[i].get_text()] = {'ltp': ap_index_price[i].get_text(), 'change': ap_index_change[i].get_text(), 'perc change': ap_index_cperc[i].get_text()}
index_data_map['ap'] = temp_ap

# %%
index_data_map
# Out:
# {'americas': {'S&P 500': {'ltp': '39,150.33',
#    'change': '-8.55',
#    'perc change': '-3.22%'},
#   'Dow Jones Industrial Average': {'ltp': '39,150.33',
#    'change': '-32.23',
#    'perc change': '+1.03%'},
#   'Nasdaq Composite': {'ltp': '5,464.62',
#    'change': '-0.080',
#    'perc change': '-1.04%'},
#   'Russell 2000 Index': {'ltp': '5,464.62',
#    'change': '-8.55',
#    'perc change': '-1.12%'},
#   'S&P/TSX Composite Index': {'ltp': '17,689.36',
#    'change': '-32.23',
#    'perc change': '+1.53%'},
#   'Brazil Stock Exchange Index': {'ltp': '17,689.36',
#    'change': '-26.49',
#    'perc change': '+1.60%'},
#   'NYSE Composite': {'ltp': '2,022.03',
#    'change': '-20.25',
#    'perc change': '+0.040%'},
#   'Dow Jones Transportation Average': {'ltp': '2,022.03',
#    'change': '-3.54',
#    'perc change': '0.040%'},
#   'Dow Jones Utility Average': {'ltp': '13.20',
#    'change': '-0.080',
#    'perc change': '-0.16%'},
#   'S&P Latin America 40': {'ltp': '13.20',
#    'change': '-3.47',
#    'perc change': '0.16%'},
#   'VIX': {'ltp': '5,464.62', 'change': '-57.25', 'perc change': '-0.18%'},
#   'Russell 1000 Index': {'ltp': '39,150.33',
#    'change': '-39.17',
#    'perc change': '0.18%'},
#   'Dow Jones U.S. Total Stock Market Index': {'ltp': '17,689.36',
#    'change': '-51.87',
#    'perc change': '+0.23%'},
#   'NASDAQ Composite Total Return': {'ltp': '2,022.03',
#    'change': '-62.39',
#    'perc change': '0.23%'},
#   'Nasdaq-100': {'ltp': '21,554.86',
#    'change': '-11.52',
#    'perc change': '-0.60%'},
#   'NASDAQ-100 Total Return': {'ltp': '121,341.13',
#    'change': '-23.27',
#    'perc change': '0.60%'},
#   'NASDAQ Transportation Index': {'ltp': '17,995.70',
#    'change': '-4.90',
#    'perc change': '0.16%'},
#   'NASDAQ Biotechnology Index': {'ltp': '15,113.33',
#    'change': '-9.63',
#    'perc change': '0.040%'},
#   'Nasdaq Financial-100': {'ltp': '909.46',
#    'change': '-108.00',
#    'perc change': '0.18%'},
#   'Nasdaq Bank': {'ltp': '2,534.02',
#    'change': '-3.09',
#    'perc change': '0.23%'},
#   'Nasdaq Insurance': {'ltp': '13.20',
#    'change': '-48.13',
#    'perc change': '0.12%'},
#   'Nasdaq Industrial': {'ltp': '2,974.97',
#    'change': '-0.55',
#    'perc change': '0.74%'},
#   'Nasdaq Computer': {'ltp': '53,892.05',
#    'change': '-1.50',
#    'perc change': '0.11%'},
#   'S&P 400': {'ltp': '21,533.48', 'change': '-71.48', 'perc change': '0.25%'}},
#  'me': {'DAX PERFORMANCE-INDEX': {'ltp': '39,150.33',
#    'change': '-8.55',
#    'perc change': '-3.22%'},
#   'FTSE 100 Index': {'ltp': '39,150.33',
#    'change': '-32.23',
#    'perc change': '+1.03%'},
#   'CAC 40': {'ltp': '5,464.62', 'change': '-0.080', 'perc change': '-1.04%'},
#   'IBEX 35': {'ltp': '5,464.62', 'change': '-90.66', 'perc change': '-1.12%'},
#   'EURO STOXX 50': {'ltp': '17,689.36',
#    'change': '-34.74',
#    'perc change': '+1.53%'},
#   'S&P EURO': {'ltp': '17,689.36',
#    'change': '-42.77',
#    'perc change': '+1.60%'},
#   'Dow Jones Germany Titans 30 Index (EUR)': {'ltp': '2,022.03',
#    'change': '-128.20',
#    'perc change': '+0.040%'},
#   'TA-125 Index': {'ltp': '2,022.03',
#    'change': '-40.43',
#    'perc change': '0.040%'},
#   'AEX index': {'ltp': '13.20', 'change': '-17.70', 'perc change': '-0.16%'},
#   'PSI-20': {'ltp': '13.20', 'change': '-3.44', 'perc change': '0.16%'},
#   'WIG': {'ltp': '18,163.52', 'change': '-10.15', 'perc change': '-0.18%'},
#   'Tadawul All-Share Index': {'ltp': '8,237.72',
#    'change': '-8.61',
#    'perc change': '0.18%'},
#   'Swiss Market Index': {'ltp': '7,628.57',
#    'change': '-80.45',
#    'perc change': '+0.23%'},
#   'S&P Europe 350': {'ltp': '11,032.30',
#    'change': '-134.01',
#    'perc change': '0.23%'},
#   'STOXX Europe 600': {'ltp': '4,907.30',
#    'change': '-115.29',
#    'perc change': '-0.60%'},
#   'FTSE AIM All-Share Index': {'ltp': '2,129.86',
#    'change': '-15.71',
#    'perc change': '0.60%'},
#   'FTSE All-Share Index': {'ltp': '548.34',
#    'change': '-3.80',
#    'perc change': '0.50%'},
#   'OMX Copenhagen 20': {'ltp': '1,927.93',
#    'change': '-17.52',
#    'perc change': '0.42%'},
#   'OMX Copenhagen 25': {'ltp': '925.23',
#    'change': '-21.85',
#    'perc change': '0.56%'},
#   'WIG20': {'ltp': '6,570.47', 'change': '-12.66', 'perc change': '1.15%'},
#   'WIG30': {'ltp': '86,415.61', 'change': '-7.91', 'perc change': '0.82%'},
#   'SBF 120': {'ltp': '11,729.97', 'change': '-6.10', 'perc change': '0.82%'},
#   'CAC LARGE 60': {'ltp': '12,012.87',
#    'change': '-37.21',
#    'perc change': '0.62%'},
#   'BIST 100': {'ltp': '2,095.31', 'change': '-48.96', 'perc change': '0.52%'},
#   'BIST 30': {'ltp': '515.11', 'change': '-62.06', 'perc change': '0.92%'},
#   'HDAX PERFORMANCE-INDEX': {'ltp': '772.57',
#    'change': '-113.94',
#    'perc change': '1.21%'},
#   'OMX Helsinki 25': {'ltp': '4,490.92',
#    'change': '-148.35',
#    'perc change': '0.15%'},
#   'SPI 20 PR': {'ltp': '2,866.72', 'change': '-11.29', 'perc change': '2.01%'},
#   'Swiss Performance Index': {'ltp': '1,971.67',
#    'change': '-41.10',
#    'perc change': '0.95%'},
#   'AMX index': {'ltp': '2,489.91', 'change': '-39.21', 'perc change': '0.74%'},
#   'BEL 20': {'ltp': '3,115.52', 'change': '-1.35', 'perc change': '0.73%'},
#   'PSI ALL-SHARE GR': {'ltp': '5,769.57',
#    'change': '-25.72',
#    'perc change': '0.025%'},
#   'Austrian Traded Index': {'ltp': '8,196.42',
#    'change': '-4.17',
#    'perc change': '0.39%'}},
#  'ap': {'Nikkei 225': {'ltp': '39,150.33',
#    'change': '-8.55',
#    'perc change': '-3.22%'},
#   'SSE Composite Index': {'ltp': '39,150.33',
#    'change': '-32.23',
#    'perc change': '+1.03%'},
#   'Hang Seng Index': {'ltp': '5,464.62',
#    'change': '-0.080',
#    'perc change': '-1.04%'},
#   'BSE SENSEX': {'ltp': '5,464.62',
#    'change': '-35.40',
#    'perc change': '-1.12%'},
#   'NIFTY 50': {'ltp': '17,689.36',
#    'change': '-212.18',
#    'perc change': '+1.53%'},
#   'S&P Asia 50': {'ltp': '17,689.36',
#    'change': '-269.03',
#    'perc change': '+1.60%'},
#   'Taiwan Capitalization Weighted Stock Index': {'ltp': '2,022.03',
#    'change': '-65.90',
#    'perc change': '+0.040%'},
#   'KOSPI': {'ltp': '2,022.03', 'change': '-170.14', 'perc change': '0.040%'},
#   'S&P/ASX 200': {'ltp': '13.20',
#    'change': '-365.10',
#    'perc change': '-0.16%'},
#   'S&P/NZX 50 Index': {'ltp': '13.20',
#    'change': '-21.62',
#    'perc change': '0.16%'},
#   'S&P BSE - 100': {'ltp': '38,689.22',
#    'change': '-52.70',
#    'perc change': '-0.18%'},
#   'TOPIX': {'ltp': '2,962.73', 'change': '-42.73', 'perc change': '0.18%'},
#   'A-share Index': {'ltp': '17,816.34',
#    'change': '-110.15',
#    'perc change': '+0.23%'},
#   'B-share Index': {'ltp': '77,209.90',
#    'change': '-37.93',
#    'perc change': '0.23%'},
#   'SZSE Component Index': {'ltp': '23,501.10',
#    'change': '-3.14',
#    'perc change': '-0.60%'},
#   'SSE 180 Index': {'ltp': '5,223.82',
#    'change': '-123.35',
#    'perc change': '0.60%'},
#   'SSE 50 Index': {'ltp': '22,888.29',
#    'change': '-39.80',
#    'perc change': '0.24%'},
#   'ChiNext': {'ltp': '2,762.64', 'change': '-4.36', 'perc change': '1.18%'},
#   'CSI 300 Index': {'ltp': '7,743.30',
#    'change': '-16.57',
#    'perc change': '1.18%'},
#   'SZSE Composite Index': {'ltp': '11,639.66',
#    'change': '-20.46',
#    'perc change': '0.35%'},
#   'S&P/HKEX GEM Index': {'ltp': '24,911.11',
#    'change': '-35.81',
#    'perc change': '0.28%'},
#   'S&P/HKEX Large Cap Index': {'ltp': '2,731.51',
#    'change': '-0.030',
#    'perc change': '3.15%'},
#   'Hang Seng China Enterprises Index': {'ltp': '3,104.95',
#    'change': '-200.82',
#    'perc change': '1.57%'},
#   'S&P BSE - 500': {'ltp': '227.17',
#    'change': '-81.24',
#    'perc change': '0.78%'},
#   'S&P BSE - 200': {'ltp': '8,941.50',
#    'change': '-128.37',
#    'perc change': '0.68%'},
#   'LQ45': {'ltp': '7,646.11', 'change': '-44.40', 'perc change': '0.37%'},
#   'IDX Composite': {'ltp': '2,394.60',
#    'change': '-0.68',
#    'perc change': '0.44%'},
#   'FTSE ASEAN All-Share Index': {'ltp': '1,739.30',
#    'change': '-53.50',
#    'perc change': '0.25%'},
#   'S&P/ASX 300': {'ltp': '3,475.16',
#    'change': '-17.66',
#    'perc change': '1.21%'},
#   'S&P/NZX 20 Index': {'ltp': '1,618.51',
#    'change': '-6.11',
#    'perc change': '1.36%'}}}

# %% [markdown]
# ## Global Currencies Data

# %%
global_currencies_url = 'https://www.google.com/finance/markets/currencies'

# %%
currencies_res = req.get(global_currencies_url)

currencies_html = bs(currencies_res.content, 'html.parser')

# %%
cur_pair_class = 'ZvmM7'
cur_ltp_class = 'YMlKec'
cur_change_class = 'P2Luy Ebnabc' # this is a span class
cur_pchange_class = 'JwB6zf' # this is a div class

# %%
cur_pair_names = currencies_html.find_all("div",class_ = cur_pair_class)
cur_pair_price = currencies_html.find_all("div",class_ = cur_ltp_class)
cur_pair_change = currencies_html.find_all("span",class_ = cur_change_class)
cur_pair_cperc = currencies_html.find_all("div",class_ = cur_pchange_class)

# %%
cur_data_map = {}

for pair in range(len( cur_pair_change )):
    cur_data_map[cur_pair_names[pair].text] = {
        'ltp': cur_pair_price[pair].text,
        'change' : cur_pair_change[pair].text,
        'perc change' : cur_pair_cperc[pair].text
    }

# %%
cur_data_map
# Out:
# {'EUR / USD': {'ltp': '0.7300', 'change': '-0.0292', 'perc change': '0.012%'},
#  'USD / JPY': {'ltp': '1.3698', 'change': '-0.0011', 'perc change': '0.23%'},
#  'GBP / USD': {'ltp': '0.2631',
#   'change': '-0.0000020',
#   'perc change': '0.30%'},
#  'USD / CAD': {'ltp': '2,022.03',
#   'change': '-0.00042',
#   'perc change': '+0.040%'},
#  'AUD / USD': {'ltp': '17,689.36',
#   'change': '-0.00042',
#   'perc change': '+1.53%'},
#  'USD / AUD': {'ltp': '17,689.36',
#   'change': '-0.00086',
#   'perc change': '+1.60%'},
#  'USD / CHF': {'ltp': '2,022.03',
#   'change': '-0.00099',
#   'perc change': '0.040%'},
#  'USD / CNY': {'ltp': '13.20', 'change': '-0.00017', 'perc change': '-0.16%'},
#  'USD / EUR': {'ltp': '13.20', 'change': '-0.000020', 'perc change': '0.16%'},
#  'USD / GBP': {'ltp': '1.0689', 'change': '-0.0380', 'perc change': '-0.18%'},
#  'USD / HKD': {'ltp': '159.6545', 'change': '-0.2115', 'perc change': '0.18%'},
#  'USD / INR': {'ltp': '1.2639', 'change': '-0.00029', 'perc change': '+0.23%'},
#  'BRL / EUR': {'ltp': '0.6636', 'change': '-0.2000', 'perc change': '-0.60%'},
#  'BRL / USD': {'ltp': '1.5068', 'change': '-0.0013', 'perc change': '0.60%'},
#  'CAD / GBP': {'ltp': '1.3698',
#   'change': '-0.00011',
#   'perc change': '0.0056%'},
#  'CAD / USD': {'ltp': '0.8934', 'change': '-0.0000', 'perc change': '0.13%'},
#  'CLP / USD': {'ltp': '7.2615',
#   'change': '-0.00012',
#   'perc change': '0.0044%'},
#  'MXN / USD': {'ltp': '0.9355',
#   'change': '-0.000052',
#   'perc change': '0.031%'},
#  'PEN / USD': {'ltp': '0.7912',
#   'change': '-0.000067',
#   'perc change': '0.049%'},
#  'CHF / EUR': {'ltp': '7.8044',
#   'change': '-0.000029',
#   'perc change': '0.057%'},
#  'CHF / GBP': {'ltp': '83.5248',
#   'change': '-0.000043',
#   'perc change': '0.031%'},
#  'CHF / USD': {'ltp': '159.6545',
#   'change': '-0.000022',
#   'perc change': '0.11%'},
#  'EUR / CHF': {'ltp': '0.1722', 'change': '-0.00011', 'perc change': '0.018%'},
#  'EUR / GBP': {'ltp': '0.1841',
#   'change': '-0.000025',
#   'perc change': '0.019%'},
#  'EUR / JPY': {'ltp': '0.5776',
#   'change': '-0.000013',
#   'perc change': '0.0025%'},
#  'GBP / CHF': {'ltp': '0.0011',
#   'change': '-0.000015',
#   'perc change': '0.045%'},
#  'GBP / EUR': {'ltp': '0.0552', 'change': '-0.000012', 'perc change': '0.13%'},
#  'PLN / USD': {'ltp': '1.0471', 'change': '-0.0000', 'perc change': '0.32%'},
#  'RUB / EUR': {'ltp': '0.8856', 'change': '-0.0000', 'perc change': '0.030%'},
#  'RUB / TRY': {'ltp': '1.1193', 'change': '-0.0000', 'perc change': '0.017%'},
#  'RUB / USD': {'ltp': '0.9550',
#   'change': '-0.0000037',
#   'perc change': '0.00%'}}

# %% [markdown]
# ## Crypto Price Data

# %%
crypto_data_url = 'https://www.google.com/finance/markets/cryptocurrencies'

# %%
crypto_pair_class = 'ZvmM7'
crypto_ltp_class = 'YMlKec'
crypto_change_class = 'P2Luy Ebnabc' # this is a span class
crypto_pchange_class = 'JwB6zf' # this is a div class

# %%
crypto_res = req.get(crypto_data_url)

crypto_html = bs(crypto_res.content, 'html.parser')

# %%
crypto_pair_names = crypto_html.find_all("div",class_ = crypto_pair_class)
crypto_pair_price = crypto_html.find_all("div",class_ = crypto_ltp_class)
crypto_pair_change = crypto_html.find_all("span",class_ = crypto_change_class)
crypto_pair_cperc = crypto_html.find_all("div",class_ = crypto_pchange_class)

# %%
crypto_data_map = {}

for pair in range(len( cur_pair_change )):
    crypto_data_map[crypto_pair_names[pair].text] = {
        'ltp': crypto_pair_price[pair].text,
        'change' : crypto_pair_change[pair].text,
        'perc change' : crypto_pair_cperc[pair].text
    }

# %%
crypto_data_map
# Out:
# {'Bitcoin (BTC / USD)': {'ltp': '39,150.33',
#   'change': '-8.55',
#   'perc change': '-3.22%'},
#  'Ether (ETH / USD)': {'ltp': '39,150.33',
#   'change': '-32.23',
#   'perc change': '+1.03%'},
#  'Cardano (ADA / USD)': {'ltp': '5,464.62',
#   'change': '-0.080',
#   'perc change': '-1.04%'},
#  'Binance Coin (BNB / USD)': {'ltp': '5,464.62',
#   'change': '-171.40',
#   'perc change': '-1.12%'},
#  'Tether (USDT / USD)': {'ltp': '17,689.36',
#   'change': '-7.96',
#   'perc change': '+1.53%'},
#  'XRP (XRP / USD)': {'ltp': '17,689.36',
#   'change': '-0.0016',
#   'perc change': '+1.60%'},
#  'Dogecoin (DOGE / USD)': {'ltp': '2,022.03',
#   'change': '-1.1710',
#   'perc change': '+0.040%'},
#  'ChainLink (LINK / USD)': {'ltp': '2,022.03',
#   'change': '-0.0035',
#   'perc change': '0.040%'},
#  'Litecoin (LTC / USD)': {'ltp': '13.20',
#   'change': '-0.00094',
#   'perc change': '-0.16%'},
#  'Bitcoin Cash (BCH / USD)': {'ltp': '13.20',
#   'change': '-0.0194',
#   'perc change': '0.16%'},
#  'Lumens (XLM / USD)': {'ltp': '63,000.00',
#   'change': '-0.68',
#   'perc change': '-0.18%'},
#  'TRON (TRX / USD)': {'ltp': '3,409.56',
#   'change': '-3.30',
#   'perc change': '0.18%'},
#  'Ethereum Classic (ETC / USD)': {'ltp': '0.3787',
#   'change': '-0.00030',
#   'perc change': '+0.23%'},
#  'Monero (XMR / USD)': {'ltp': '576.4150',
#   'change': '-0.00038',
#   'perc change': '0.23%'},
#  'EOS (EOS / USD)': {'ltp': '0.9995',
#   'change': '-0.0127',
#   'perc change': '-0.60%'},
#  'NEO (NEO / USD)': {'ltp': '0.4766',
#   'change': '-0.0110',
#   'perc change': '0.60%'},
#  'Waves (WAVES / USD)': {'ltp': '0.1214',
#   'change': '-0.0193',
#   'perc change': '0.27%'},
#  'Dash (DASH / USD)': {'ltp': '13.1852',
#   'change': '-0.0412',
#   'perc change': '0.23%'},
#  'OmiseGO (OMG / USD)': {'ltp': '72.64',
#   'change': '-0.00015',
#   'perc change': '0.41%'},
#  'Decred (DCR / USD)': {'ltp': '377.54',
#   'change': '-0.00030',
#   'perc change': '0.20%'},
#  'NEM (XEM / USD)': {'ltp': '0.0892',
#   'change': '-0.5658',
#   'perc change': '0.052%'},
#  'Decentraland (MANA / USD)': {'ltp': '0.1189',
#   'change': '-0.0011',
#   'perc change': '0.74%'},
#  'ICON (ICX / USD)': {'ltp': '22.7706',
#   'change': '-0.000072',
#   'perc change': '0.77%'},
#  'Qtum (QTUM / USD)': {'ltp': '164.1738',
#   'change': '-0.000015',
#   'perc change': '0.15%'},
#  'Zilliqa (ZIL / USD)': {'ltp': '0.5610',
#   'change': '-0.0250',
#   'perc change': '0.93%'},
#  'Basic Attention Token (BAT / USD)': {'ltp': '10.9108',
#   'change': '-0.4331',
#   'perc change': '0.87%'},
#  'Bitgem (BTG / USD)': {'ltp': '6.0467',
#   'change': '-0.00013',
#   'perc change': '0.34%'},
#  'Bancor (BNT / USD)': {'ltp': '23.4838',
#   'change': '-0.000051',
#   'perc change': '0.32%'},
#  '0x (ZRX / USD)': {'ltp': '0.3132',
#   'change': '-0.0040',
#   'perc change': '0.46%'},
#  'Siacoin (SC / USD)': {'ltp': '14.7764',
#   'change': '-0.000011',
#   'perc change': '0.0015%'},
#  'Ontology (ONT / USD)': {'ltp': '0.0136',
#   'change': '-0.0011',
#   'perc change': '0.18%'},
#  'DigiByte (DGB / USD)': {'ltp': '0.3257',
#   'change': '-0.0000',
#   'perc change': '0.12%'},
#  'Nano (NANO / USD)': {'ltp': '0.1488',
#   'change': '-0.0019',
#   'perc change': '0.18%'},
#  'Lisk (LSK / USD)': {'ltp': '2.5035',
#   'change': '-0.0000030',
#   'perc change': '0.082%'},
#  'Gnosis (GNO / USD)': {'ltp': '0.0167',
#   'change': '-0.000023',
#   'perc change': '1.14%'}}

# %% [markdown]
# ## Top Ganiers and Top Losers

# %%
top_gainers_url = 'https://www.google.com/finance/markets/gainers'
top_losers_url = 'https://www.google.com/finance/markets/losers'

# %%
tg_res = req.get(top_gainers_url)
tl_res = req.get(top_losers_url)

tg_html = bs(tg_res.content, 'html.parser')
tl_html = bs(tl_res.content, 'html.parser')

# %%
tg_name_class = 'ZvmM7'
tg_ltp_class = 'YMlKec'
tg_change_class = 'P2Luy Ez2Ioe' # this is a span class
tg_pchange_class = 'V53LMb' # this is a span class 

tl_name_class = 'ZvmM7'
tl_ltp_class = 'YMlKec'
tl_change_class = 'P2Luy Ebnabc' # this is a span class
tl_pchange_class = 'JwB6zf' # this is a div class

# %%
tg_names = tg_html.find_all("div",class_ = tg_name_class)
tg_price = tg_html.find_all("div",class_ = tg_ltp_class)
tg_change = tg_html.find_all("span",class_ = tg_change_class)
tg_cperc = tg_html.find_all("span",class_ = tg_pchange_class)

tl_names = tl_html.find_all("div",class_ = tl_name_class)
tl_price = tl_html.find_all("div",class_ = tl_ltp_class)
tl_change = tl_html.find_all("span",class_ = tl_change_class)
tl_cperc = tl_html.find_all("div",class_ = tl_pchange_class)

# %%
tg_data_list, tl_data_list = [], []

for i in range(len( tg_names )):
    tg_data_list.append({
        'name':tg_names[i].text,
        'ltp': tg_price[i].text,
        'change' : tg_change[i].text,
        'perc change' : tg_cperc[i].text
    })


for j in range(len( tl_names )):
    tl_data_list.append( {
        'name':tl_names[j].text,
        'ltp': tl_price[j].text,
        'change' : tl_change[j].text,
        'perc change' : tl_cperc[j].text
    })

# %%
tg_data_list
# Out:
# [{'name': 'Sarepta Therapeutics Inc',
#   'ltp': '39,150.33',
#   'change': '+15.57',
#   'perc change': ''},
#  {'name': 'Asana Inc',
#   'ltp': '39,150.33',
#   'change': '+4.64',
#   'perc change': ''},
#  {'name': 'Super Hi International Holding American Depositary Shares',
#   'ltp': '5,464.62',
#   'change': '+$37.22',
#   'perc change': ''},
#  {'name': 'Immunitybio Inc',
#   'ltp': '5,464.62',
#   'change': '+$1.74',
#   'perc change': ''},
#  {'name': 'Highest Performances Holdings Inc',
#   'ltp': '17,689.36',
#   'change': '+$2.02',
#   'perc change': ''},
#  {'name': 'PTC Therapeutics, Inc.',
#   'ltp': '17,689.36',
#   'change': '+$0.76',
#   'perc change': ''},
#  {'name': 'Medicinova Inc',
#   'ltp': '2,022.03',
#   'change': '+$0.76',
#   'perc change': ''},
#  {'name': 'Joby Aviation Inc',
#   'ltp': '2,022.03',
#   'change': '+$3.23',
#   'perc change': ''},
#  {'name': 'Dyne Therapeutics Inc',
#   'ltp': '13.20',
#   'change': '+$0.11',
#   'perc change': ''},
#  {'name': 'ADT Inc', 'ltp': '13.20', 'change': '+$0.39', 'perc change': ''},
#  {'name': 'Rocket Pharmaceuticals Inc',
#   'ltp': '$160.72',
#   'change': '+$2.63',
#   'perc change': ''},
#  {'name': 'Ryan Specialty Holdings Inc',
#   'ltp': '$13.11',
#   'change': '+$0.57',
#   'perc change': ''},
#  {'name': 'Arrowhead Pharmaceuticals Inc',
#   'ltp': '$17.98',
#   'change': '+$1.63',
#   'perc change': ''},
#  {'name': 'Agios Pharmaceuticals Inc',
#   'ltp': '$7.26',
#   'change': '+$4.24',
#   'perc change': ''},
#  {'name': 'Bilibili Inc - ADR',
#   'ltp': '$8.20',
#   'change': '+$1.71',
#   'perc change': ''},
#  {'name': 'Prestige Consumer Healthcare Inc',
#   'ltp': '$36.52',
#   'change': '+$2.77',
#   'perc change': ''},
#  {'name': 'Spirit AeroSystems Holdings Inc',
#   'ltp': '$1.39',
#   'change': '+$1.09',
#   'perc change': ''},
#  {'name': 'BBB Foods Inc',
#   'ltp': '$5.19',
#   'change': '+$4.12',
#   'perc change': ''},
#  {'name': 'Denali Therapeutics Inc',
#   'ltp': '$35.02',
#   'change': '+$1.90',
#   'perc change': ''},
#  {'name': 'Dropbox Inc',
#   'ltp': '$7.75',
#   'change': '+$1.28',
#   'perc change': ''},
#  {'name': 'Aurora Innovation Inc',
#   'ltp': '$22.48',
#   'change': '+$1.23',
#   'perc change': ''},
#  {'name': 'Nuscale Power Corp',
#   'ltp': '$59.60',
#   'change': '+$1.17',
#   'perc change': ''},
#  {'name': 'Alnylam Pharmaceuticals, Inc.',
#   'ltp': '$25.50',
#   'change': '+$0.12',
#   'perc change': ''},
#  {'name': 'UiPath Inc',
#   'ltp': '$45.22',
#   'change': '+$0.51',
#   'perc change': ''},
#  {'name': 'Ascendis Pharma A/S',
#   'ltp': '$18.14',
#   'change': '+$8.30',
#   'perc change': ''},
#  {'name': 'MicroSectors Gold Miners 3X Inverse Leveraged ETN',
#   'ltp': '$69.40',
#   'change': '+$0.59',
#   'perc change': ''},
#  {'name': 'Insmed Inc',
#   'ltp': '$33.56',
#   'change': '+$6.23',
#   'perc change': ''},
#  {'name': 'Tempus AI Inc',
#   'ltp': '$23.41',
#   'change': '+$1.12',
#   'perc change': ''},
#  {'name': 'GraniteShares 2x Short NVDA Daily ETF',
#   'ltp': '$22.63',
#   'change': '+$3.28',
#   'perc change': ''},
#  {'name': 'Viking Therapeutics Inc',
#   'ltp': '$22.13',
#   'change': '+$1.38',
#   'perc change': ''},
#  {'name': 'Twist Bioscience Corp',
#   'ltp': '$2.33',
#   'change': '+$0.10',
#   'perc change': ''},
#  {'name': 'Legend Biotech Corp',
#   'ltp': '$10.02',
#   'change': '+$2.31',
#   'perc change': ''},
#  {'name': 'Repligen Corp',
#   'ltp': '$165.70',
#   'change': '+$2.23',
#   'perc change': ''},
#  {'name': 'Sunrun Inc',
#   'ltp': '$11.96',
#   'change': '+$1.81',
#   'perc change': ''},
#  {'name': 'Rocket Lab USA Inc',
#   'ltp': '$127.85',
#   'change': '+$5.32',
#   'perc change': ''},
#  {'name': 'Companhia Energetica Minas Gerais ADR Repstg One Pref Shs',
#   'ltp': '$23.11',
#   'change': '+$0.55',
#   'perc change': ''},
#  {'name': 'Sportradar Group AG',
#   'ltp': '$67.99',
#   'change': '+$0.21',
#   'perc change': ''},
#  {'name': 'Geron Corp',
#   'ltp': '$28.64',
#   'change': '+$0.080',
#   'perc change': ''},
#  {'name': 'Ultragenyx Pharmaceutical Inc',
#   'ltp': '$2.13',
#   'change': '+$0.46',
#   'perc change': ''},
#  {'name': 'Marqeta Inc',
#   'ltp': '$52.74',
#   'change': '+$0.19',
#   'perc change': ''},
#  {'name': 'Mattel Inc',
#   'ltp': '$50.97',
#   'change': '+$1.58',
#   'perc change': ''},
#  {'name': 'Scotts Miracle-Gro Co',
#   'ltp': '$42.61',
#   'change': '+$0.21',
#   'perc change': ''},
#  {'name': 'Remitly Global Inc',
#   'ltp': '$125.32',
#   'change': '+$0.71',
#   'perc change': ''},
#  {'name': 'Madrigal Pharmaceuticals Inc',
#   'ltp': '$13.09',
#   'change': '+$2.66',
#   'perc change': ''},
#  {'name': 'TG Therapeutics Inc common stock',
#   'ltp': '$5.01',
#   'change': '+$0.47',
#   'perc change': ''},
#  {'name': 'HUTCHMED (China) Ltd',
#   'ltp': '$1.91',
#   'change': '+$10.63',
#   'perc change': ''},
#  {'name': 'Basic Sant Cpy of the Sta Pul SBSP',
#   'ltp': '$11.07',
#   'change': '+$0.67',
#   'perc change': ''},
#  {'name': 'Agilysys Inc',
#   'ltp': '$4.65',
#   'change': '+$0.67',
#   'perc change': ''},
#  {'name': 'HubSpot Inc',
#   'ltp': '$39.60',
#   'change': '+$0.51',
#   'perc change': ''},
#  {'name': 'Corporacion America Airports SA',
#   'ltp': '$5.27',
#   'change': '+$3.63',
#   'perc change': ''}]

# %%
tl_data_list
# Out:
# [{'name': 'AST SpaceMobile Inc',
#   'ltp': '39,150.33',
#   'change': '-8.55',
#   'perc change': '-3.22%'},
#  {'name': 'CleanSpark Inc',
#   'ltp': '39,150.33',
#   'change': '-32.23',
#   'perc change': '+1.03%'},
#  {'name': 'VinFast Auto Ltd',
#   'ltp': '5,464.62',
#   'change': '-0.080',
#   'perc change': '-1.04%'},
#  {'name': 'Bloom Energy Corp',
#   'ltp': '5,464.62',
#   'change': '-$1.14',
#   'perc change': '-1.12%'},
#  {'name': 'Riot Platforms Inc',
#   'ltp': '17,689.36',
#   'change': '-$1.88',
#   'perc change': '+1.53%'},
#  {'name': 'Warrior Met Coal Inc',
#   'ltp': '17,689.36',
#   'change': '-$0.41',
#   'perc change': '+1.60%'},
#  {'name': 'Trex Co Inc',
#   'ltp': '2,022.03',
#   'change': '-$1.19',
#   'perc change': '+0.040%'},
#  {'name': 'Marathon Digital Holdings Inc',
#   'ltp': '2,022.03',
#   'change': '-$0.87',
#   'perc change': '0.040%'},
#  {'name': 'AeroVironment, Inc.',
#   'ltp': '13.20',
#   'change': '-$4.96',
#   'perc change': '-0.16%'},
#  {'name': 'Palantir Technologies Inc',
#   'ltp': '13.20',
#   'change': '-$6.01',
#   'perc change': '0.16%'},
#  {'name': 'Astera Labs Inc',
#   'ltp': '$10.08',
#   'change': '-$1.45',
#   'perc change': '-0.18%'},
#  {'name': 'GameStop Corp',
#   'ltp': '$17.29',
#   'change': '-$14.11',
#   'perc change': '0.18%'},
#  {'name': 'Zeekr Intellignt Tchnlgy Hldng Ltd',
#   'ltp': '$3.90',
#   'change': '-$1.72',
#   'perc change': '+0.23%'},
#  {'name': 'Crispr Therapeutics AG',
#   'ltp': '$12.82',
#   'change': '-$4.15',
#   'perc change': '0.23%'},
#  {'name': 'Arch Resources Inc',
#   'ltp': '$9.55',
#   'change': '-$1.66',
#   'perc change': '-0.60%'},
#  {'name': 'On Holding AG',
#   'ltp': '$61.50',
#   'change': '-$1.38',
#   'perc change': '0.60%'},
#  {'name': 'Azek Company Inc',
#   'ltp': '$78.01',
#   'change': '-$3.36',
#   'perc change': '10.16%'},
#  {'name': 'Instacart',
#   'ltp': '$19.21',
#   'change': '-$7.91',
#   'perc change': '9.81%'},
#  {'name': 'Arhaus Inc',
#   'ltp': '$189.48',
#   'change': '-$2.01',
#   'perc change': '9.51%'},
#  {'name': 'Dlocal Ltd',
#   'ltp': '$23.84',
#   'change': '-$2.23',
#   'perc change': '8.49%'},
#  {'name': 'Brookfield Business Partners LP',
#   'ltp': '$59.01',
#   'change': '-$1.57',
#   'perc change': '8.35%'},
#  {'name': 'Paramount Global Class A',
#   'ltp': '$23.93',
#   'change': '-$0.84',
#   'perc change': '7.46%'},
#  {'name': 'Broadcom Inc',
#   'ltp': '$21.16',
#   'change': '-$0.36',
#   'perc change': '7.15%'},
#  {'name': 'Symbotic Inc',
#   'ltp': '$56.24',
#   'change': '-$0.84',
#   'perc change': '7.02%'},
#  {'name': 'Ferrovial SE',
#   'ltp': '$149.05',
#   'change': '-$0.79',
#   'perc change': '6.93%'},
#  {'name': 'Apellis Pharmaceuticals Inc',
#   'ltp': '$39.72',
#   'change': '-$75.93',
#   'perc change': '6.73%'},
#  {'name': 'Equinox Gold Corp',
#   'ltp': '$44.50',
#   'change': '-$1.48',
#   'perc change': '6.57%'},
#  {'name': 'Coinbase Global Inc',
#   'ltp': '$31.51',
#   'change': '-$1.68',
#   'perc change': '6.49%'},
#  {'name': 'Autohome Inc',
#   'ltp': '$17.09',
#   'change': '-$1.66',
#   'perc change': '6.12%'},
#  {'name': 'Uranium Energy Corp.',
#   'ltp': '$7.48',
#   'change': '-$0.23',
#   'perc change': '5.64%'},
#  {'name': 'First Majestic Silver Corp',
#   'ltp': '$17.49',
#   'change': '-$9.17',
#   'perc change': '5.04%'},
#  {'name': 'Loar Holdings Inc',
#   'ltp': '$16.87',
#   'change': '-$1.05',
#   'perc change': '4.82%'},
#  {'name': 'Kanzhun Ltd',
#   'ltp': '$1,658.63',
#   'change': '-$0.24',
#   'perc change': '4.77%'},
#  {'name': 'ICU Medical Inc',
#   'ltp': '$32.53',
#   'change': '-$0.24',
#   'perc change': '4.75%'},
#  {'name': 'iShares Silver Trust',
#   'ltp': '$37.92',
#   'change': '-$2.19',
#   'perc change': '4.68%'},
#  {'name': 'Paymentus Holdings Inc',
#   'ltp': '$38.07',
#   'change': '-$0.77',
#   'perc change': '4.59%'},
#  {'name': 'Resmed Inc',
#   'ltp': '$5.31',
#   'change': '-$4.45',
#   'perc change': '4.58%'},
#  {'name': 'Lazard Inc',
#   'ltp': '$225.86',
#   'change': '-$1.02',
#   'perc change': '4.47%'},
#  {'name': 'TransMedics Group Inc',
#   'ltp': '$26.35',
#   'change': '-$0.68',
#   'perc change': '4.38%'},
#  {'name': 'Rubrik Inc',
#   'ltp': '$6.12',
#   'change': '-$7.44',
#   'perc change': '4.35%'},
#  {'name': 'Peabody Energy Corp',
#   'ltp': '$6.15',
#   'change': '-$1.31',
#   'perc change': '4.24%'},
#  {'name': 'Iamgold Corp',
#   'ltp': '$56.20',
#   'change': '-$4.96',
#   'perc change': '4.18%'},
#  {'name': 'Crescent Energy Co',
#   'ltp': '$20.00',
#   'change': '-$1.02',
#   'perc change': '4.15%'},
#  {'name': 'Recursion Pharmaceuticals Inc',
#   'ltp': '$116.10',
#   'change': '-$0.77',
#   'perc change': '3.90%'},
#  {'name': 'Trip.com Group Ltd',
#   'ltp': '$26.98',
#   'change': '-$0.13',
#   'perc change': '3.83%'},
#  {'name': 'Fortrea Holdings Inc',
#   'ltp': '$18.71',
#   'change': '-$0.40',
#   'perc change': '3.77%'},
#  {'name': 'PLDT Inc ADR',
#   'ltp': '$205.83',
#   'change': '-$0.30',
#   'perc change': '3.76%'},
#  {'name': 'Micron Technology Inc',
#   'ltp': '$36.40',
#   'change': '-$1.63',
#   'perc change': '3.75%'},
#  {'name': 'Evercore Inc',
#   'ltp': '$139.04',
#   'change': '-$0.78',
#   'perc change': '3.71%'},
#  {'name': 'NVIDIA Corp',
#   'ltp': '$28.65',
#   'change': '-$0.78',
#   'perc change': '3.69%'}]
