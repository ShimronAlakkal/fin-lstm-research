# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Function to plot the log periodic graph
def plot_log_periodic_graph(df):
    # Ensure the DataFrame contains the necessary columns
    required_columns = ['date', 'close']
    for col in required_columns:
        if col not in df.columns:
            raise ValueError(f"Missing required column: {col}")

    # Convert 'date' column to datetime if it's not already
    if not np.issubdtype(df['date'].dtype, np.datetime64):
        df['date'] = pd.to_datetime(df['date'])

    # Sort the DataFrame by date
    df = df.sort_values('date')

    # Calculate the logarithm of the closing prices
    df['log_close'] = np.log(df['close'])

    # Plot the log prices
    plt.figure(figsize=(14, 7))
    plt.plot(df['date'], df['log_close'], label='Log(Close Price)', color='blue')
    
    # Calculate a simple moving average to help identify potential bubbles
    window_size = 30  # You can adjust the window size
    df['SMA'] = df['log_close'].rolling(window=window_size).mean()

    # Plot the moving average
    plt.plot(df['date'], df['SMA'], label='Simple Moving Average', color='orange')

    # Add labels and legend
    plt.xlabel('Date')
    plt.ylabel('Log(Close Price)')
    plt.title('Log Periodic Graph of Close Prices')
    plt.legend()
    plt.grid(True)
    plt.show()

# Example usage
if __name__ == "__main__":
    # Create a sample DataFrame
    data = {
        'date': pd.date_range(start='2021-01-01', periods=100, freq='D'),
        'open': np.random.rand(100) * 100,
        'high': np.random.rand(100) * 100,
        'low': np.random.rand(100) * 100,
        'close': np.random.rand(100) * 100,
        'volume': np.random.randint(1, 1000, 100),
        'adjusted_volume': np.random.randint(1, 1000, 100)
    }
    df = pd.DataFrame(data)

    # Plot the log periodic graph
    plot_log_periodic_graph(df)

# %%
# import all the unclean data for aal five stocks into separate variables 
uDataAmazon = pd.read_csv('./data/Amazon.csv', index_col = False)
uDataApple = pd.read_csv('./data/Apple.csv')
uDataGoogle = pd.read_csv('./data/Google.csv')
uDataNetflix = pd.read_csv('./data/Netflix.csv')
uDataMicrosoft = pd.read_csv('./data/Microsoft.csv')

# combine all the temp data values into a list to perform mapping operations
uDataList = [ uDataAmazon, uDataApple, uDataGoogle, uDataMicrosoft, uDataNetflix ]

# %%
# clean data of amazon
cDataAmazon = uDataAmazon[['Date', 'Close']]
tempDataAmazon = cDataAmazon.copy()
cDataAmazon
# Out:
#             Date       Close
# 0     2000-01-03    4.468750
# 1     2000-01-04    4.096875
# 2     2000-01-05    3.487500
# 3     2000-01-06    3.278125
# 4     2000-01-07    3.478125
# ...          ...         ...
# 5834  2023-03-13   92.430000
# 5835  2023-03-14   94.879997
# 5836  2023-03-15   96.199997
# 5837  2023-03-16  100.040001
# 5838  2023-03-17   98.949997
#
# [5839 rows x 2 columns]

# %%
plt.plot(tempDataAmazon['Date'], tempDataAmazon['Close'])
plt.show()

# %%
df = pd.read_csv('stock_symbols.csv')
df.head()
# Out:
#   Symbol                                              Name Last Sale  \
# 0      A            Agilent Technologies Inc. Common Stock   $130.57
# 1     AA                   Alcoa Corporation Common Stock     $38.54
# 2   AACG  ATA Creativity Global American Depositary Shares     $0.81
# 3   AACI           Armada Acquisition Corp. I Common Stock   $11.465
# 4  AACIW                Armada Acquisition Corp. I Warrant   $0.1217
#
#    Net Change % Change    Market Cap        Country  IPO Year   Volume  \
# 0     -2.5900  -1.945%  3.809522e+10  United States    1999.0  2555441
# 1     -1.1700  -2.946%  6.920230e+09  United States    2016.0  4358445
# 2     -0.0400  -4.706%  2.592010e+07          China    2008.0     2922
# 3      0.0600   0.526%  0.000000e+00  United States    2021.0    15832
# 4      0.0107    9.64%  0.000000e+00  United States    2021.0    46030
#
#         Sector                                          Industry
# 0  Industrials  Biotechnology: Laboratory Analytical Instruments
# 1  Industrials                                          Aluminum
# 2  Real Estate                           Other Consumer Services
# 3      Finance                                      Blank Checks
# 4      Finance                                      Blank Checks

# %%
symbols = list(df['Symbol'])
names = list(df['Name'])
sectors = list(df['Sector'])

sectors
# Out:
# ['Industrials',
#  'Industrials',
#  'Real Estate',
#  'Finance',
#  'Finance',
#  'Finance',
#  'Health Care',
#  'Consumer Staples',
#  'Consumer Staples',
#  'Consumer Discretionary',
#  'Finance',
#  'Finance',
#  'Miscellaneous',
#  'Technology',
#  'Industrials',
#  'Consumer Discretionary',
#  'Technology',
#  'Real Estate',
#  'Finance',
#  'Basic Materials',
#  'Health Care',
#  'Finance',
#  'Health Care',
#  'Health Care',
#  'Consumer Staples',
#  'Consumer Discretionary',
#  'Health Care',
#  'Finance',
#  'Finance',
#  'Finance',
#  'Consumer Discretionary',
#  'Consumer Discretionary',
#  'Finance',
#  'Finance',
#  'Health Care',
#  'Real Estate',
#  nan,
#  nan,
#  nan,
#  'Health Care',
#  'Health Care',
#  'Technology',
#  'Health Care',
#  'Health Care',
#  'Health Care',
#  'Finance',
#  'Industrials',
#  'Finance',
#  'Finance',
#  'Finance',
#  'Finance',
#  'Health Care',
#  'Health Care',
#  'Consumer Discretionary',
#  'Consumer Discretionary',
#  'Energy',
#  'Consumer Discretionary',
#  'Health Care',
#  'Finance',
#  'Finance',
#  'Finance',
#  'Health Care',
#  'Health Care',
#  'Industrials',
#  'Health Care',
#  'Consumer Staples',
#  'Finance',
#  'Health Care',
#  'Technology',
#  'Technology',
#  'Health Care',
#  'Consumer Discretionary',
#  'Technology',
#  'Technology',
#  'Finance',
#  'Industrials',
#  'Health Care',
#  'Health Care',
#  'Finance',
#  nan,
#  'Real Estate',
#  nan,
#  nan,
#  'Real Estate',
#  'Health Care',
#  'Health Care',
#  'Health Care',
#  'Finance',
#  'Miscellaneous',
#  'Consumer Discretionary',
#  'Finance',
#  'Consumer Discretionary',
#  'Health Care',
#  'Health Care',
#  'Health Care',
#  'Technology',
#  'Real Estate',
#  nan,
#  'Health Care',
#  'Consumer Discretionary',
#  'Technology',
#  'Technology',
#  'Health Care',
#  'Consumer Staples',
#  'Health Care',
#  'Miscellaneous',
#  'Consumer Discretionary',
#  'Utilities',
#  'Technology',
#  'Health Care',
#  'Finance',
#  'Consumer Discretionary',
#  'Consumer Discretionary',
#  'Technology',
#  'Consumer Discretionary',
#  'Technology',
#  'Technology',
#  'Telecommunications',
#  'Health Care',
#  'Health Care',
#  'Consumer Discretionary',
#  'Health Care',
#  'Consumer Discretionary',
#  'Finance',
#  'Health Care',
#  'Energy',
#  'Finance',
#  'Finance',
#  'Finance',
#  'Utilities',
#  'Finance',
#  nan,
#  'Finance',
#  'Consumer Discretionary',
#  'Industrials',
#  'Finance',
#  'Technology',
#  'Basic Materials',
#  'Health Care',
#  'Consumer Discretionary',
#  'Consumer Discretionary',
#  'Consumer Discretionary',
#  'Health Care',
#  'Utilities',
#  'Consumer Discretionary',
#  'Consumer Discretionary',
#  'Consumer Discretionary',
#  'Utilities',
#  'Industrials',
#  'Consumer Discretionary',
#  'Technology',
#  'Health Care',
#  'Finance',
#  'Finance',
#  'Finance',
#  'Finance',
#  'Finance',
#  'Finance',
#  'Finance',
#  'Finance',
#  'Finance',
#  nan,
#  nan,
#  'Finance',
#  'Health Care',
#  'Consumer Staples',
#  'Consumer Staples',
#  'Finance',
#  'Finance',
#  'Real Estate',
#  'Basic Materials',
#  'Telecommunications',
#  'Finance',
#  'Finance',
#  'Industrials',
#  'Finance',
#  'Health Care',
#  'Consumer Staples',
#  'Basic Materials',
#  'Health Care',
#  'Health Care',
#  'Finance',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'Technology',
#  'Real Estate',
#  'Real Estate',
#  'Real Estate',
#  'Real Estate',
#  'Real Estate',
#  'Real Estate',
#  'Finance',
#  'Utilities',
#  'Industrials',
#  'Industrials',
#  'Consumer Staples',
#  'Consumer Discretionary',
#  'Consumer Discretionary',
#  'Technology',
#  'Health Care',
#  'Consumer Discretionary',
#  'Finance',
#  nan,
#  nan,
#  nan,
#  nan,
#  'Real Estate',
#  'Real Estate',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'Technology',
#  'Finance',
#  'Finance',
#  'Finance',
#  'Technology',
#  'Technology',
#  'Health Care',
#  'Finance',
#  'Health Care',
#  'Health Care',
#  'Consumer Discretionary',
#  'Consumer Discretionary',
#  'Finance',
#  'Technology',
#  'Industrials',
#  'Real Estate',
#  'Finance',
#  'Technology',
#  'Industrials',
#  'Finance',
#  'Finance',
#  'Health Care',
#  'Consumer Discretionary',
#  'Consumer Discretionary',
#  'Technology',
#  'Technology',
#  'Industrials',
#  nan,
#  nan,
#  'Real Estate',
#  'Real Estate',
#  'Technology',
#  'Finance',
#  'Finance',
#  'Finance',
#  'Real Estate',
#  'Consumer Discretionary',
#  'Consumer Discretionary',
#  'Health Care',
#  'Health Care',
#  'Health Care',
#  nan,
#  nan,
#  'Real Estate',
#  'Health Care',
#  'Utilities',
#  'Health Care',
#  'Industrials',
#  'Consumer Discretionary',
#  nan,
#  'Technology',
#  'Technology',
#  'Industrials',
#  nan,
#  'Health Care',
#  'Health Care',
#  'Utilities',
#  nan,
#  'Finance',
#  'Health Care',
#  'Utilities',
#  'Health Care',
#  'Real Estate',
#  nan,
#  'Industrials',
#  'Technology',
#  'Health Care',
#  'Health Care',
#  'Consumer Discretionary',
#  'Health Care',
#  'Health Care',
#  'Consumer Discretionary',
#  'Consumer Discretionary',
#  'Health Care',
#  'Technology',
#  'Finance',
#  nan,
#  nan,
#  nan,
#  nan,
#  'Consumer Discretionary',
#  'Consumer Discretionary',
#  'Health Care',
#  'Health Care',
#  'Health Care',
#  'Telecommunications',
#  'Finance',
#  'Industrials',
#  'Health Care',
#  'Technology',
#  'Telecommunications',
#  'Technology',
#  'Health Care',
#  'Finance',
#  'Finance',
#  'Finance',
#  'Finance',
#  'Finance',
#  'Consumer Discretionary',
#  'Health Care',
#  'Industrials',
#  nan,
#  'Finance',
#  'Industrials',
#  'Industrials',
#  'Technology',
#  'Health Care',
#  'Consumer Discretionary',
#  'Health Care',
#  'Health Care',
#  'Health Care',
#  'Real Estate',
#  'Health Care',
#  'Health Care',
#  'Utilities',
#  'Finance',
#  'Technology',
#  'Technology',
#  'Finance',
#  'Industrials',
#  'Real Estate',
#  'Industrials',
#  'Consumer Discretionary',
#  'Consumer Discretionary',
#  'Telecommunications',
#  'Technology',
#  'Industrials',
#  'Health Care',
#  'Finance',
#  'Health Care',
#  'Real Estate',
#  nan,
#  nan,
#  'Health Care',
#  'Finance',
#  'Technology',
#  'Basic Materials',
#  'Health Care',
#  'Health Care',
#  'Finance',
#  'Telecommunications',
#  'Telecommunications',
#  'Health Care',
#  'Technology',
#  'Utilities',
#  'Miscellaneous',
#  'Energy',
#  'Energy',
#  'Consumer Discretionary',
#  'Industrials',
#  'Health Care',
#  'Health Care',
#  'Health Care',
#  'Industrials',
#  'Finance',
#  'Technology',
#  'Technology',
#  'Real Estate',
#  'Finance',
#  'Finance',
#  'Industrials',
#  'Consumer Discretionary',
#  'Consumer Discretionary',
#  'Telecommunications',
#  'Consumer Discretionary',
#  'Consumer Discretionary',
#  'Health Care',
#  'Industrials',
#  'Health Care',
#  'Telecommunications',
#  'Consumer Discretionary',
#  nan,
#  nan,
#  'Consumer Discretionary',
#  'Consumer Discretionary',
#  'Consumer Discretionary',
#  'Health Care',
#  'Health Care',
#  'Health Care',
#  'Health Care',
#  'Health Care',
#  'Health Care',
#  'Health Care',
#  nan,
#  nan,
#  nan,
#  nan,
#  'Consumer Discretionary',
#  'Health Care',
#  'Health Care',
#  'Finance',
#  'Finance',
#  'Technology',
#  'Finance',
#  'Finance',
#  nan,
#  'Industrials',
#  'Technology',
#  'Consumer Discretionary',
#  'Industrials',
#  'Energy',
#  'Finance',
#  'Finance',
#  'Technology',
#  'Technology',
#  'Industrials',
#  'Health Care',
#  'Real Estate',
#  'Consumer Discretionary',
#  'Health Care',
#  'Technology',
#  'Technology',
#  'Finance',
#  'Real Estate',
#  'Health Care',
#  'Health Care',
#  'Health Care',
#  'Health Care',
#  'Health Care',
#  'Finance',
#  nan,
#  'Consumer Discretionary',
#  'Finance',
#  'Technology',
#  'Technology',
#  'Technology',
#  'Miscellaneous',
#  'Health Care',
#  nan,
#  'Health Care',
#  'Consumer Discretionary',
#  'Health Care',
#  'Industrials',
#  'Finance',
#  'Health Care',
#  'Consumer Staples',
#  'Industrials',
#  'Utilities',
#  'Utilities',
#  'Utilities',
#  'Health Care',
#  'Finance',
#  'Energy',
#  'Health Care',
#  'Technology',
#  'Technology',
#  'Technology',
#  'Finance',
#  'Finance',
#  'Consumer Discretionary',
#  'Industrials',
#  'Finance',
#  'Energy',
#  'Consumer Discretionary',
#  'Health Care',
#  'Finance',
#  'Health Care',
#  'Real Estate',
#  'Industrials',
#  'Energy',
#  'Technology',
#  'Finance',
#  'Finance',
#  nan,
#  'Health Care',
#  'Consumer Discretionary',
#  'Real Estate',
#  'Energy',
#  'Consumer Staples',
#  'Consumer Staples',
#  'Consumer Discretionary',
#  'Real Estate',
#  'Consumer Staples',
#  'Energy',
#  'Technology',
#  'Consumer Discretionary',
#  nan,
#  'Health Care',
#  'Energy',
#  'Finance',
#  'Industrials',
#  'Technology',
#  'Technology',
#  'Health Care',
#  'Real Estate',
#  nan,
#  'Consumer Discretionary',
#  'Health Care',
#  'Health Care',
#  'Utilities',
#  'Industrials',
#  'Health Care',
#  'Technology',
#  'Health Care',
#  'Health Care',
#  'Consumer Discretionary',
#  'Industrials',
#  'Consumer Staples',
#  'Technology',
#  'Finance',
#  nan,
#  nan,
#  'Finance',
#  'Consumer Discretionary',
#  'Finance',
#  'Finance',
#  'Finance',
#  'Consumer Discretionary',
#  'Consumer Discretionary',
#  'Industrials',
#  'Consumer Discretionary',
#  'Health Care',
#  'Basic Materials',
#  'Health Care',
#  'Technology',
#  'Health Care',
#  'Telecommunications',
#  'Consumer Discretionary',
#  'Industrials',
#  'Consumer Discretionary',
#  'Consumer Discretionary',
#  'Consumer Discretionary',
#  'Health Care',
#  'Finance',
#  'Technology',
#  'Industrials',
#  'Industrials',
#  'Consumer Discretionary',
#  'Technology',
#  'Industrials',
#  'Industrials',
#  'Consumer Discretionary',
#  'Consumer Discretionary',
#  'Consumer Discretionary',
#  'Technology',
#  'Technology',
#  'Health Care',
#  'Technology',
#  'Health Care',
#  'Consumer Discretionary',
#  'Finance',
#  nan,
#  nan,
#  'Basic Materials',
#  'Health Care',
#  'Finance',
#  'Telecommunications',
#  nan,
#  'Telecommunications',
#  'Real Estate',
#  'Technology',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'Health Care',
#  'Health Care',
#  'Technology',
#  nan,
#  'Industrials',
#  'Consumer Discretionary',
#  'Health Care',
#  'Miscellaneous',
#  'Finance',
#  'Finance',
#  'Finance',
#  'Finance',
#  'Finance',
#  'Industrials',
#  'Finance',
#  'Consumer Discretionary',
#  'Finance',
#  'Health Care',
#  'Health Care',
#  'Telecommunications',
#  'Health Care',
#  'Utilities',
#  'Technology',
#  'Health Care',
#  'Health Care',
#  'Industrials',
#  'Health Care',
#  'Health Care',
#  'Health Care',
#  'Industrials',
#  nan,
#  'Consumer Discretionary',
#  'Telecommunications',
#  'Consumer Discretionary',
#  'Health Care',
#  'Health Care',
#  'Health Care',
#  'Basic Materials',
#  'Finance',
#  nan,
#  'Finance',
#  'Utilities',
#  'Consumer Discretionary',
#  'Technology',
#  'Technology',
#  nan,
#  'Basic Materials',
#  'Health Care',
#  'Health Care',
#  'Technology',
#  'Health Care',
#  'Technology',
#  nan,
#  'Health Care',
#  'Technology',
#  'Technology',
#  'Utilities',
#  'Health Care',
#  'Finance',
#  'Industrials',
#  'Real Estate',
#  'Health Care',
#  'Industrials',
#  'Health Care',
#  'Technology',
#  'Technology',
#  'Health Care',
#  'Health Care',
#  'Finance',
#  'Health Care',
#  'Industrials',
#  'Technology',
#  'Consumer Staples',
#  'Technology',
#  'Technology',
#  'Health Care',
#  'Technology',
#  'Health Care',
#  'Industrials',
#  'Health Care',
#  'Health Care',
#  'Consumer Discretionary',
#  'Finance',
#  'Health Care',
#  'Industrials',
#  'Industrials',
#  'Industrials',
#  'Utilities',
#  'Finance',
#  'Utilities',
#  'Technology',
#  'Utilities',
#  'Finance',
#  'Industrials',
#  'Health Care',
#  'Consumer Discretionary',
#  'Consumer Discretionary',
#  'Health Care',
#  'Industrials',
#  'Finance',
#  'Real Estate',
#  'Finance',
#  nan,
#  'Health Care',
#  'Consumer Discretionary',
#  'Technology',
#  'Utilities',
#  'Consumer Discretionary',
#  'Consumer Discretionary',
#  'Health Care',
#  nan,
#  'Industrials',
#  'Health Care',
#  'Consumer Discretionary',
#  'Technology',
#  'Technology',
#  'Health Care',
#  'Consumer Discretionary',
#  'Industrials',
#  'Industrials',
#  'Industrials',
#  'Consumer Discretionary',
#  'Finance',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'Finance',
#  'Health Care',
#  'Consumer Discretionary',
#  'Consumer Discretionary',
#  'Finance',
#  'Consumer Discretionary',
#  'Industrials',
#  'Industrials',
#  'Consumer Discretionary',
#  nan,
#  'Finance',
#  nan,
#  'Technology',
#  'Finance',
#  'Finance',
#  'Energy',
#  'Finance',
#  'Finance',
#  'Consumer Discretionary',
#  'Finance',
#  'Consumer Discretionary',
#  'Technology',
#  'Energy',
#  'Consumer Discretionary',
#  'Consumer Discretionary',
#  'Health Care',
#  nan,
#  nan,
#  nan,
#  'Technology',
#  'Finance',
#  'Consumer Discretionary',
#  'Finance',
#  'Finance',
#  'Finance',
#  'Consumer Discretionary',
#  'Health Care',
#  'Health Care',
#  'Health Care',
#  'Finance',
#  'Consumer Discretionary',
#  'Consumer Discretionary',
#  nan,
#  'Finance',
#  'Consumer Discretionary',
#  'Consumer Discretionary',
#  'Consumer Discretionary',
#  'Consumer Discretionary',
#  nan,
#  nan,
#  nan,
#  'Health Care',
#  'Finance',
#  nan,
#  'Finance',
#  'Finance',
#  'Consumer Discretionary',
#  'Health Care',
#  'Health Care',
#  nan,
#  'Finance',
#  'Finance',
#  'Finance',
#  'Health Care',
#  'Finance',
#  'Consumer Discretionary',
#  'Technology',
#  'Finance',
#  'Industrials',
#  'Health Care',
#  'Finance',
#  'Finance',
#  'Finance',
#  'Finance',
#  'Finance',
#  'Health Care',
#  'Health Care',
#  'Finance',
#  nan,
#  'Finance',
#  'Health Care',
#  'Telecommunications',
#  'Finance',
#  'Consumer Discretionary',
#  'Real Estate',
#  'Health Care',
#  'Health Care',
#  'Health Care',
#  'Health Care',
#  'Energy',
#  'Health Care',
#  'Health Care',
#  'Health Care',
#  'Consumer Discretionary',
#  'Real Estate',
#  'Technology',
#  'Finance',
#  'Finance',
#  nan,
#  nan,
#  'Finance',
#  'Finance',
#  'Finance',
#  'Utilities',
#  nan,
#  nan,
#  'Utilities',
#  'Utilities',
#  'Utilities',
#  'Industrials',
#  'Industrials',
#  'Finance',
#  'Finance',
#  nan,
#  nan,
#  'Finance',
#  'Consumer Discretionary',
#  'Finance',
#  'Consumer Discretionary',
#  'Consumer Discretionary',
#  'Consumer Discretionary',
#  'Finance',
#  'Finance',
#  'Health Care',
#  'Health Care',
#  'Health Care',
#  'Health Care',
#  'Health Care',
#  'Real Estate',
#  nan,
#  nan,
#  'Finance',
#  'Finance',
#  'Consumer Staples',
#  'Finance',
#  'Finance',
#  'Consumer Discretionary',
#  'Finance',
#  nan,
#  'Health Care',
#  'Health Care',
#  'Finance',
#  'Consumer Staples',
#  'Consumer Discretionary',
#  'Finance',
#  'Finance',
#  'Health Care',
#  'Finance',
#  'Consumer Discretionary',
#  'Finance',
#  'Finance',
#  'Consumer Discretionary',
#  'Finance',
#  'Health Care',
#  'Technology',
#  'Finance',
#  'Finance',
#  'Finance',
#  'Finance',
#  'Finance',
#  'Finance',
#  'Consumer Staples',
#  'Finance',
#  'Finance',
#  'Real Estate',
#  'Energy',
#  'Real Estate',
#  nan,
#  nan,
#  'Finance',
#  'Finance',
#  'Health Care',
#  'Health Care',
#  'Health Care',
#  'Technology',
#  'Consumer Discretionary',
#  'Technology',
#  nan,
#  'Health Care',
#  'Technology',
#  'Technology',
#  'Health Care',
#  'Industrials',
#  nan,
#  'Health Care',
#  'Health Care',
#  'Industrials',
#  'Utilities',
#  nan,
#  nan,
#  'Consumer Discretionary',
#  nan,
#  'Consumer Discretionary',
#  nan,
#  'Consumer Discretionary',
#  'Consumer Discretionary',
#  'Finance',
#  'Finance',
#  'Finance',
#  'Health Care',
#  'Consumer Discretionary',
#  'Health Care',
#  'Consumer Discretionary',
#  'Finance',
#  'Health Care',
#  'Consumer Discretionary',
#  'Utilities',
#  nan,
#  nan,
#  nan,
#  'Finance',
#  'Finance',
#  'Consumer Discretionary',
#  'Industrials',
#  'Technology',
#  'Finance',
#  'Technology',
#  'Finance',
#  'Technology',
#  'Technology',
#  'Finance',
#  'Finance',
#  'Finance',
#  'Consumer Discretionary',
#  'Technology',
#  nan,
#  'Consumer Discretionary',
#  'Consumer Discretionary',
#  'Consumer Discretionary',
#  'Energy',
#  'Consumer Discretionary',
#  'Finance',
#  'Finance',
#  'Finance',
#  'Finance',
#  'Health Care',
#  'Finance',
#  'Technology',
#  'Finance',
#  'Technology',
#  'Consumer Discretionary',
#  'Technology',
#  'Consumer Discretionary',
#  'Health Care',
#  'Health Care',
#  'Finance',
#  'Health Care',
#  'Consumer Discretionary',
#  'Finance',
#  'Technology',
#  'Finance',
#  'Technology',
#  'Finance',
#  'Health Care',
#  'Finance',
#  'Industrials',
#  nan,
#  nan,
#  nan,
#  nan,
#  'Finance',
#  nan,
#  'Technology',
#  'Health Care',
#  'Finance',
#  'Health Care',
#  'Finance',
#  'Health Care',
#  'Real Estate',
#  'Technology',
#  'Technology',
#  'Consumer Discretionary',
#  'Industrials',
#  'Real Estate',
#  'Finance',
#  'Finance',
#  'Finance',
#  'Real Estate',
#  'Real Estate',
#  'Health Care',
#  'Health Care',
#  'Finance',
#  'Industrials',
#  'Finance',
#  'Health Care',
#  'Health Care',
#  'Finance',
#  'Technology',
#  'Technology',
#  'Finance',
#  'Finance',
#  'Finance',
#  'Finance',
#  'Consumer Discretionary',
#  'Finance',
#  ...]

# %%
with open('symbols.txt', 'w') as file:
    for i in range(len(symbols)):
        name = names[i].replace("'",'')
        sector = str(sectors[i]).replace("'",'')
        line = f"{{ 'symbol': '{symbols[i]}', 'name': '{name}', 'sector': '{sector}'}}"
        file.write(line + ',\n')

# %%
def check_trend_or_range(df, num_divisions):
    # Ensure data is sorted by date
    df = df.sort_values('Date').reset_index(drop=True)
    
    # Determine the number of rows per division
    rows_per_division = len(df) // num_divisions
    
    results = []
    
    for i in range(num_divisions):
        # Select the division's data
        start_idx = i * rows_per_division
        end_idx = (i + 1) * rows_per_division if i < num_divisions - 1 else len(df)
        division_data = df.iloc[start_idx:end_idx]
        
        # Calculate trend and range metrics
        start_price = division_data['Close'].iloc[0]
        end_price = division_data['Close'].iloc[-1]
        high_price = division_data['High'].max()
        low_price = division_data['Low'].min()
        
        trend = end_price - start_price
        price_range = high_price - low_price
        
        # Define a simple rule to determine trend vs range
        if abs(trend) > 0.5 * price_range:
            results.append('Trending')
        else:
            results.append('Ranging')
    
    return results

# Example usage
# Assuming 'df' is your DataFrame with the required columns: Date, Open, High, Low, Close, Adj Close
# num_divisions defines how many segments you want to divide the data into

# df = pd.DataFrame({
#     'Date': pd.date_range(start='2023-01-01', periods=100),
#     'Open': np.random.uniform(100, 200, 100),
#     'High': np.random.uniform(100, 200, 100),
#     'Low': np.random.uniform(100, 200, 100),
#     'Close': np.random.uniform(100, 200, 100),
#     'Adj Close': np.random.uniform(100, 200, 100)
# })

# Divide data into 5 equal divisions and check for trend or range
num_divisions = 5
result = check_trend_or_range(uDataAmazon, num_divisions)
print(result)
# Out:
# ['Trending', 'Ranging', 'Trending', 'Ranging', 'Ranging']
